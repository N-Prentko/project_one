# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import requests
import json
from api_key import data_gov_key
import sys

# Study data files
presidential_votes_path = "1976-2016-president.csv"

# Read the presidential votes csv
presidential_votes_data = pd.read_csv(presidential_votes_path)

# %%
presidential_votes_df = pd.DataFrame(presidential_votes_data)

# %%
presidential_votes_df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  Alabama       AL           1         63        41  US President
# 1     1976  Alabama       AL           1         63        41  US President
# 2     1976  Alabama       AL           1         63        41  US President
# 3     1976  Alabama       AL           1         63        41  US President
# 4     1976  Alabama       AL           1         63        41  US President
# ...    ...      ...      ...         ...        ...       ...           ...
# 3735  2016  Wyoming       WY          56         83        68  US President
# 3736  2016  Wyoming       WY          56         83        68  US President
# 3737  2016  Wyoming       WY          56         83        68  US President
# 3738  2016  Wyoming       WY          56         83        68  US President
# 3739  2016  Wyoming       WY          56         83        68  US President
#
#                     candidate                       party  writein  \
# 0               Carter, Jimmy                    democrat    False
# 1                Ford, Gerald                  republican    False
# 2              Maddox, Lester  american independent party    False
# 3     Bubar, Benjamin ""Ben""                 prohibition    False
# 4                   Hall, Gus         communist party use    False
# ...                       ...                         ...      ...
# 3735                      NaN                         NaN     True
# 3736                      NaN                 independent    False
# 3737               Blank Vote                         NaN    False
# 3738       Castle, Darrell L.          constitution party    False
# 3739                Over Vote                         NaN    False
#
#       candidatevotes  totalvotes   version  notes
# 0             659170     1182850  20171015    NaN
# 1             504070     1182850  20171015    NaN
# 2               9198     1182850  20171015    NaN
# 3               6669     1182850  20171015    NaN
# 4               1954     1182850  20171015    NaN
# ...              ...         ...       ...    ...
# 3735            6904      258788  20171015    NaN
# 3736            3224      258788  20171015    NaN
# 3737            2661      258788  20171015    NaN
# 3738            2042      258788  20171015    NaN
# 3739             278      258788  20171015    NaN
#
# [3740 rows x 14 columns]

# %%
presidential_votes_df= presidential_votes_df.drop(['state_fips', 'state_cen', 'state_ic',
                 'office', 'party', 'writein', 'totalvotes',
                 'version', 'notes'], axis=1)

# %%
presidential_votes_df.head()
# Out:
#    year    state state_po                candidate  candidatevotes
# 0  1976  Alabama       AL            Carter, Jimmy          659170
# 1  1976  Alabama       AL             Ford, Gerald          504070
# 2  1976  Alabama       AL           Maddox, Lester            9198
# 3  1976  Alabama       AL  Bubar, Benjamin ""Ben""            6669
# 4  1976  Alabama       AL                Hall, Gus            1954

# %%
presidential_votes_df.rename(columns = {'state_po':'contributor_state'}, inplace = True)

# %%
presidential_votes_df
# Out:
#       year    state contributor_state                candidate  candidatevotes
# 0     1976  Alabama                AL            Carter, Jimmy          659170
# 1     1976  Alabama                AL             Ford, Gerald          504070
# 2     1976  Alabama                AL           Maddox, Lester            9198
# 3     1976  Alabama                AL  Bubar, Benjamin ""Ben""            6669
# 4     1976  Alabama                AL                Hall, Gus            1954
# ...    ...      ...               ...                      ...             ...
# 3735  2016  Wyoming                WY                      NaN            6904
# 3736  2016  Wyoming                WY                      NaN            3224
# 3737  2016  Wyoming                WY               Blank Vote            2661
# 3738  2016  Wyoming                WY       Castle, Darrell L.            2042
# 3739  2016  Wyoming                WY                Over Vote             278
#
# [3740 rows x 5 columns]

# %%
presidential_votes_df = presidential_votes_df.loc[presidential_votes_df['year'] == 2016]

# %%
presidential_votes_df.head()
# Out:
#       year    state contributor_state         candidate  candidatevotes
# 3395  2016  Alabama                AL  Trump, Donald J.         1318255
# 3396  2016  Alabama                AL  Clinton, Hillary          729547
# 3397  2016  Alabama                AL     Johnson, Gary           44467
# 3398  2016  Alabama                AL               NaN           21712
# 3399  2016  Alabama                AL       Stein, Jill            9391

# %%
pres_finance = pd.DataFrame()

# %%
# testing getting values from the FEC api
cand_url = 'https://api.open.fec.gov/v1/presidential/contributions/by_candidate/'

# set the amount of data to be returned per page. Must be under 100
per_page = 50

params = {"api_key" : data_gov_key,
         "election_year" : "2016",
         "per_page" : per_page}

# first json request to get the number of pages to loop through
cand_search = requests.get(cand_url, params=params)

# json'ing it up
cand_search = cand_search.json()

# stores the number of pages the search returns
page_nums = cand_search['pagination']['pages']

print(json.dumps(cand_search, indent=4))
# Out:
# {
#     "api_version": "1.0",
#     "pagination": {
#         "pages": 34,
#         "per_page": 50,
#         "count": 1669,
#         "page": 1
#     },
#     "results": [
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 1462.3,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 1462314770.13
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 799.4,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 799419661.15
#         },
#         {
#             "candidate_last_name": "Republicans",
#             "rounded_net_receipts": 639.1,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P00000003",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 639144333.21
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 563.8,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 563756927.19
#         },
#         {
#             "candidate_last_name": "Trump",
#             "rounded_net_receipts": 333.1,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P80001571",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 333127163.91
#         },
#         {
#             "candidate_last_name": "Sanders",
#             "rounded_net_receipts": 228.2,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P60007168",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 228164500.68
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 172.0,
#             "contributor_state": "NY",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 171976015.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 153.9,
#             "contributor_state": "NY",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 153904479.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 152.3,
#             "contributor_state": "CA",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 152306310.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 145.2,
#             "contributor_state": "NY",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 145248693.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 114.5,
#             "contributor_state": "CA",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 114485560.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 93.7,
#             "contributor_state": "CA",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 93681171.0
#         },
#         {
#             "candidate_last_name": "Cruz",
#             "rounded_net_receipts": 90.2,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P60006111",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 90203163.84
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 75.9,
#             "contributor_state": "TX",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 75857465.0
#         },
#         {
#             "candidate_last_name": "Carson",
#             "rounded_net_receipts": 63.6,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P60005915",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 63622853.54
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 58.1,
#             "contributor_state": "FL",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 58095188.0
#         },
#         {
#             "candidate_last_name": "Republicans",
#             "rounded_net_receipts": 49.1,
#             "contributor_state": "TX",
#             "election_year": 2016,
#             "candidate_id": "P00000003",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 49070876.0
#         },
#         {
#             "candidate_last_name": "Rubio",
#             "rounded_net_receipts": 42.1,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P60006723",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 42106430.38
#         },
#         {
#             "candidate_last_name": "Republicans",
#             "rounded_net_receipts": 36.5,
#             "contributor_state": "CA",
#             "election_year": 2016,
#             "candidate_id": "P00000003",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 36453786.0
#         },
#         {
#             "candidate_last_name": "Bush",
#             "rounded_net_receipts": 34.1,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P60008059",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 34088583.28
#         },
#         {
#             "candidate_last_name": "Republicans",
#             "rounded_net_receipts": 32.2,
#             "contributor_state": "FL",
#             "election_year": 2016,
#             "candidate_id": "P00000003",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 32225392.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 31.4,
#             "contributor_state": "MA",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 31390178.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 28.6,
#             "contributor_state": "VA",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 28630861.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 28.4,
#             "contributor_state": "IL",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 28438374.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 26.4,
#             "contributor_state": "MA",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 26409930.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 26.3,
#             "contributor_state": "TX",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 26331445.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 25.5,
#             "contributor_state": "FL",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 25519391.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 25.2,
#             "contributor_state": "PA",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 25200015.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 25.0,
#             "contributor_state": "NJ",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 24969453.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 24.5,
#             "contributor_state": "MD",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 24488945.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 24.4,
#             "contributor_state": "WA",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 24417819.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 22.6,
#             "contributor_state": "TX",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 22623321.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 21.9,
#             "contributor_state": "FL",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 21917413.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 21.4,
#             "contributor_state": "MA",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 21377210.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 20.5,
#             "contributor_state": "DC",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 20486652.0
#         },
#         {
#             "candidate_last_name": "Sanders",
#             "rounded_net_receipts": 20.2,
#             "contributor_state": "CA",
#             "election_year": 2016,
#             "candidate_id": "P60007168",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 20240643.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 20.0,
#             "contributor_state": "OH",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 20010753.0
#         },
#         {
#             "candidate_last_name": "Cruz",
#             "rounded_net_receipts": 19.8,
#             "contributor_state": "TX",
#             "election_year": 2016,
#             "candidate_id": "P60006111",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 19751236.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 19.7,
#             "contributor_state": "MD",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 19723304.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 19.7,
#             "contributor_state": "IL",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 19701510.0
#         },
#         {
#             "candidate_last_name": "Kasich",
#             "rounded_net_receipts": 18.9,
#             "contributor_state": "US",
#             "election_year": 2016,
#             "candidate_id": "P60003670",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 18897172.03
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 18.5,
#             "contributor_state": "WA",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 18489510.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 18.4,
#             "contributor_state": "DC",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 18416054.0
#         },
#         {
#             "candidate_last_name": "Democrats",
#             "rounded_net_receipts": 18.3,
#             "contributor_state": "VA",
#             "election_year": 2016,
#             "candidate_id": "P00000002",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 18284486.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 17.7,
#             "contributor_state": "GA",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 17698117.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 17.6,
#             "contributor_state": "DC",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 17626471.0
#         },
#         {
#             "candidate_last_name": "Republicans",
#             "rounded_net_receipts": 17.5,
#             "contributor_state": "NY",
#             "election_year": 2016,
#             "candidate_id": "P00000003",
#             "candidate_party_affiliation": "REP",
#             "net_receipts": 17513009.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 17.1,
#             "contributor_state": "CO",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 17087918.0
#         },
#         {
#             "candidate_last_name": "All candidates",
#             "rounded_net_receipts": 16.2,
#             "contributor_state": "MI",
#             "election_year": 2016,
#             "candidate_id": "P00000001",
#             "candidate_party_affiliation": null,
#             "net_receipts": 16203120.0
#         },
#         {
#             "candidate_last_name": "Clinton",
#             "rounded_net_receipts": 16.2,
#             "contributor_state": "MD",
#             "election_year": 2016,
#             "candidate_id": "P00003392",
#             "candidate_party_affiliation": "DEM",
#             "net_receipts": 16198896.0
#         }
#     ]
# }

# %%
# creating lists to store the data to pass to a dataframe
id_list = []
net_rec_list = []
contr_state_list = []
can_last_name = []
can_party = []

for page in range(1, page_nums):
    params['page'] = page
    cand_data = requests.get(cand_url, params=params)
    cand_data = cand_data.json()
    
#     print(json.dumps(cand_data, indent=4))
    for result in range(0, per_page):
        try:
            id_list.append(cand_data['results'][result]['candidate_id'])
            net_rec_list.append(cand_data['results'][result]['rounded_net_receipts'])
            contr_state_list.append(cand_data['results'][result]['contributor_state'])
            can_last_name.append(cand_data['results'][result]['candidate_last_name'])
            can_party.append(cand_data['results'][result]['candidate_party_affiliation'])
            print("Data appended")
        except:
            print("Data out of range/not found...")
# Out:
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended
# Data appended

# %%
pres_finance = pd.DataFrame({'candidate_id' : id_list,
                             'candidate_party' : can_party,
                             'candidate_last_name' : can_last_name,
                            'rounded_net_receipts' : net_rec_list,
                           'contributor_state' : contr_state_list})
pres_finance
# Out:
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts  \
# 0       P00000001            None      All candidates                1462.3
# 1       P00000002             DEM           Democrats                 799.4
# 2       P00000003             REP         Republicans                 639.1
# 3       P00003392             DEM             Clinton                 563.8
# 4       P80001571             REP               Trump                 333.1
# ...           ...             ...                 ...                   ...
# 1645    P00000002             DEM           Democrats                   0.0
# 1646    P00003392             DEM             Clinton                   0.0
# 1647    P00000001            None      All candidates                   0.0
# 1648    P00000002             DEM           Democrats                   0.0
# 1649    P00003392             DEM             Clinton                   0.0
#
#      contributor_state
# 0                   US
# 1                   US
# 2                   US
# 3                   US
# 4                   US
# ...                ...
# 1645                KE
# 1646                BE
# 1647                BE
# 1648                BE
# 1649                ZU
#
# [1650 rows x 5 columns]

# %%
cand_search['results'][0]['rounded_net_receipts']
# Out:
# 1462.3

# %%
page_nums = 2
params['page'] = page_nums
params
# Out:
# {'api_key': 'y7OEg0YLriSiwo3o1L90fShNhSBEYQxkHgB1Ey3d',
#  'election_year': '2016',
#  'per_page': 50,
#  'page': 2}

# %%
# Generate a bar plot showing the number of mice per time point for each treatment throughout the course of the study using pyplot.


contributions_candidates_by_state = pres_finance.groupby("contributor_state").count()["rounded_net_receipts"]
pyplot_bar_state = pd.DataFrame(contributions_candidates_by_state)

also = pyplot_bar_state.plot.bar(legend=False,rot=50)
also
plt.xlabel("Individual States")
plt.ylabel("Rounded Net Receipts")
plt.title("Don't Use Me")
plt.savefig("output/pyplot_bar_state")

# %%
state_list = ["AL", "AK","AZ","AR","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI",
              "MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX",
             "UT","VT","VA","WA","WV","WI","WY"]

# %%
pres_finance_states=pres_finance["contributor_state"].isin(state_list)
pres_finance[pres_finance_states]
states_df = pd.DataFrame(pres_finance[pres_finance_states])

# %%
states_df
# Out:
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts  \
# 6       P00000001            None      All candidates                 172.0
# 7       P00000002             DEM           Democrats                 153.9
# 9       P00003392             DEM             Clinton                 145.2
# 13      P00000001            None      All candidates                  75.9
# 15      P00000001            None      All candidates                  58.1
# ...           ...             ...                 ...                   ...
# 1582    P60007697             REP              Graham                   0.0
# 1586    P20003281             REP               Perry                   0.0
# 1587    P20003281             REP               Perry                   0.0
# 1589    P80003478             REP            Huckabee                   0.0
# 1597    P20003281             REP               Perry                   0.0
#
#      contributor_state
# 6                   NY
# 7                   NY
# 9                   NY
# 13                  TX
# 15                  FL
# ...                ...
# 1582                ME
# 1586                UT
# 1587                MD
# 1589                VT
# 1597                AR
#
# [1258 rows x 5 columns]

# %%
states_receipts = states_df.groupby("contributor_state").count()["rounded_net_receipts"]
pyplot_bar_United_States = pd.DataFrame(states_receipts)

also = pyplot_bar_United_States.plot(kind='bar', stacked=True, figsize=(20,10), fontsize=18)
also
plt.xlabel("United States (initials)")
plt.ylabel("Rounded Net Receipts ($mil)")
plt.title("Rounded Net Receipts Per State")
plt.savefig("output/pyplot_bar_United_States")

# %%
# 
pres_finance_countries=~pres_finance["contributor_state"].isin(state_list)
pres_finance[pres_finance_countries]
countries_df = pd.DataFrame(pres_finance[pres_finance_countries])
countries_df
# Out:
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts  \
# 0       P00000001            None      All candidates                1462.3
# 1       P00000002             DEM           Democrats                 799.4
# 2       P00000003             REP         Republicans                 639.1
# 3       P00003392             DEM             Clinton                 563.8
# 4       P80001571             REP               Trump                 333.1
# ...           ...             ...                 ...                   ...
# 1645    P00000002             DEM           Democrats                   0.0
# 1646    P00003392             DEM             Clinton                   0.0
# 1647    P00000001            None      All candidates                   0.0
# 1648    P00000002             DEM           Democrats                   0.0
# 1649    P00003392             DEM             Clinton                   0.0
#
#      contributor_state
# 0                   US
# 1                   US
# 2                   US
# 3                   US
# 4                   US
# ...                ...
# 1645                KE
# 1646                BE
# 1647                BE
# 1648                BE
# 1649                ZU
#
# [392 rows x 5 columns]

# %%
countries_receipts = countries_df.groupby("contributor_state").count()["rounded_net_receipts"]
pyplot_bar_countries = pd.DataFrame(countries_receipts)

also = pyplot_bar_countries.plot(kind='bar', stacked=True, figsize=(20,10), fontsize=18)
also
plt.xlabel("Countries By Initials")
plt.ylabel("Rounded Net Receipts ($mil)")
plt.title("Rounded Net Receipts Per Country")
plt.savefig("output/pyplot_bar_countries")

# %%
# Combine the data into a single dataset
combined_df = pd.merge(presidential_votes_df,states_df, on=("contributor_state"))
combined_df
# Out:
#       year    state contributor_state         candidate  candidatevotes  \
# 0     2016  Alabama                AL  Trump, Donald J.         1318255
# 1     2016  Alabama                AL  Trump, Donald J.         1318255
# 2     2016  Alabama                AL  Trump, Donald J.         1318255
# 3     2016  Alabama                AL  Trump, Donald J.         1318255
# 4     2016  Alabama                AL  Trump, Donald J.         1318255
# ...    ...      ...               ...               ...             ...
# 8578  2016  Wyoming                WY         Over Vote             278
# 8579  2016  Wyoming                WY         Over Vote             278
# 8580  2016  Wyoming                WY         Over Vote             278
# 8581  2016  Wyoming                WY         Over Vote             278
# 8582  2016  Wyoming                WY         Over Vote             278
#
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts
# 0       P00000001            None      All candidates                   6.4
# 1       P00000003             REP         Republicans                   4.2
# 2       P00000002             DEM           Democrats                   2.2
# 3       P80001571             REP               Trump                   2.0
# 4       P00003392             DEM             Clinton                   1.9
# ...           ...             ...                 ...                   ...
# 8578    P80003379             REP             Gilmore                   0.0
# 8579    P20003984             GRE               Stein                   0.0
# 8580    P60022654             IND            McMullin                   0.0
# 8581    P60009685             DEM              Lessig                   0.0
# 8582    P20003281             REP               Perry                   0.0
#
# [8583 rows x 9 columns]

# %%
dollar_per_vote_state = combined_df.groupby("contributor_state").count()["rounded_net_receipts"]
pyplot_dollars_per_vote_state = pd.DataFrame(dollar_per_vote_state)

also = pyplot_dollars_per_vote_state.plot(kind='bar', stacked=True, figsize=(20,10), fontsize=18)
also
plt.xlabel("United States (initials)")
plt.ylabel("Rounded Net Receipts ($mil)")
plt.title("U.S. Dollar Per Vote For Respective States")
plt.savefig("output/pyplot_bar_countries")

# %%
combined_df
# Out:
#       year    state contributor_state         candidate  candidatevotes  \
# 0     2016  Alabama                AL  Trump, Donald J.         1318255
# 1     2016  Alabama                AL  Trump, Donald J.         1318255
# 2     2016  Alabama                AL  Trump, Donald J.         1318255
# 3     2016  Alabama                AL  Trump, Donald J.         1318255
# 4     2016  Alabama                AL  Trump, Donald J.         1318255
# ...    ...      ...               ...               ...             ...
# 8578  2016  Wyoming                WY         Over Vote             278
# 8579  2016  Wyoming                WY         Over Vote             278
# 8580  2016  Wyoming                WY         Over Vote             278
# 8581  2016  Wyoming                WY         Over Vote             278
# 8582  2016  Wyoming                WY         Over Vote             278
#
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts
# 0       P00000001            None      All candidates                   6.4
# 1       P00000003             REP         Republicans                   4.2
# 2       P00000002             DEM           Democrats                   2.2
# 3       P80001571             REP               Trump                   2.0
# 4       P00003392             DEM             Clinton                   1.9
# ...           ...             ...                 ...                   ...
# 8578    P80003379             REP             Gilmore                   0.0
# 8579    P20003984             GRE               Stein                   0.0
# 8580    P60022654             IND            McMullin                   0.0
# 8581    P60009685             DEM              Lessig                   0.0
# 8582    P20003281             REP               Perry                   0.0
#
# [8583 rows x 9 columns]

# %%
total_clinton = combined_df.loc[combined_df['candidate']=="Clinton, Hillary"]
total_clinton
# Out:
#       year    state contributor_state         candidate  candidatevotes  \
# 26    2016  Alabama                AL  Clinton, Hillary          729547
# 27    2016  Alabama                AL  Clinton, Hillary          729547
# 28    2016  Alabama                AL  Clinton, Hillary          729547
# 29    2016  Alabama                AL  Clinton, Hillary          729547
# 30    2016  Alabama                AL  Clinton, Hillary          729547
# ...    ...      ...               ...               ...             ...
# 8428  2016  Wyoming                WY  Clinton, Hillary           55973
# 8429  2016  Wyoming                WY  Clinton, Hillary           55973
# 8430  2016  Wyoming                WY  Clinton, Hillary           55973
# 8431  2016  Wyoming                WY  Clinton, Hillary           55973
# 8432  2016  Wyoming                WY  Clinton, Hillary           55973
#
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts
# 26      P00000001            None      All candidates                   6.4
# 27      P00000003             REP         Republicans                   4.2
# 28      P00000002             DEM           Democrats                   2.2
# 29      P80001571             REP               Trump                   2.0
# 30      P00003392             DEM             Clinton                   1.9
# ...           ...             ...                 ...                   ...
# 8428    P80003379             REP             Gilmore                   0.0
# 8429    P20003984             GRE               Stein                   0.0
# 8430    P60022654             IND            McMullin                   0.0
# 8431    P60009685             DEM              Lessig                   0.0
# 8432    P20003281             REP               Perry                   0.0
#
# [1342 rows x 9 columns]

# %%
clinton_df = total_clinton.groupby("contributor_state").count()["rounded_net_receipts"]
pyplot_bar_clinton = pd.DataFrame(clinton_df)

also = pyplot_bar_clinton.plot(kind='bar', stacked=True, figsize=(20,10), fontsize=18)
also
plt.xlabel("United States (initials)")
plt.ylabel("Rounded Net Receipts ($mil)")
plt.title("Clinton's Rounded Net REceipts Per State")
plt.savefig("output/pyplot_bar_clinton_net_receipts_per_state")

# %%
Votes_per_state_clinton =total_clinton.groupby("contributor_state").count()["rounded_net_receipts"]

# %%
Using the new pandas release (0.14.0 or later) the below code will work. To create the two axis I have manually created two matplotlib axes objects (ax and ax2) which will serve for both bar plots.

When plotting a Dataframe you can choose the axes object using ax=.... Also in order to prevent the two plots from overlapping I have modified where they align with the position keyword argument, this defaults to 0.5 but that would mean the two bar plots overlapping.

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from io import StringIO

s = StringIO("""     amount     price
A     40929   4066443
B     93904   9611272
C    188349  19360005
D    248438  24335536
E    205622  18888604
F    140173  12580900
G     76243   6751731
H     36859   3418329
I     29304   2758928
J     39768   3201269
K     30350   2867059""")

df = pd.read_csv(s, index_col=0, delimiter=' ', skipinitialspace=True)

fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df.amount.plot(kind='bar', color='red', ax=ax, width=width, position=1)
df.price.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_ylabel('Amount')
ax2.set_ylabel('Price')

plt.show()
# Out:
#   File "<ipython-input-32-982dfd760159>", line 1
#     Using the new pandas release (0.14.0 or later) the below code will work. To create the two axis I have manually created two matplotlib axes objects (ax and ax2) which will serve for both bar plots.
#             ^
# SyntaxError: invalid syntax

# %%
total_trump = combined_df.loc[combined_df['candidate']=="Trump, Donald J."]
total_trump
# Out:
#       year    state contributor_state         candidate  candidatevotes  \
# 0     2016  Alabama                AL  Trump, Donald J.         1318255
# 1     2016  Alabama                AL  Trump, Donald J.         1318255
# 2     2016  Alabama                AL  Trump, Donald J.         1318255
# 3     2016  Alabama                AL  Trump, Donald J.         1318255
# 4     2016  Alabama                AL  Trump, Donald J.         1318255
# ...    ...      ...               ...               ...             ...
# 8403  2016  Wyoming                WY  Trump, Donald J.          174419
# 8404  2016  Wyoming                WY  Trump, Donald J.          174419
# 8405  2016  Wyoming                WY  Trump, Donald J.          174419
# 8406  2016  Wyoming                WY  Trump, Donald J.          174419
# 8407  2016  Wyoming                WY  Trump, Donald J.          174419
#
#      candidate_id candidate_party candidate_last_name  rounded_net_receipts
# 0       P00000001            None      All candidates                   6.4
# 1       P00000003             REP         Republicans                   4.2
# 2       P00000002             DEM           Democrats                   2.2
# 3       P80001571             REP               Trump                   2.0
# 4       P00003392             DEM             Clinton                   1.9
# ...           ...             ...                 ...                   ...
# 8403    P80003379             REP             Gilmore                   0.0
# 8404    P20003984             GRE               Stein                   0.0
# 8405    P60022654             IND            McMullin                   0.0
# 8406    P60009685             DEM              Lessig                   0.0
# 8407    P20003281             REP               Perry                   0.0
#
# [1314 rows x 9 columns]

# %%
trump_df = total_trump.groupby("contributor_state").count()["rounded_net_receipts"]
pyplot_bar_trump = pd.DataFrame(trump_df)

also = pyplot_bar_trump.plot(kind='bar', stacked=True, figsize=(20,10), fontsize=18)
also
plt.xlabel("United States (initials)")
plt.ylabel("Rounded Net Receipts ($mil)")
plt.title("Trump's Rounded Net REceipts Per State")
plt.savefig("output/pyplot_bar_trump_net_receipts_per_state")
